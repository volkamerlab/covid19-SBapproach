# %%
# %load_ext nb_black

# %%
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
import pandas as pd
from os import listdir
from os.path import isfile, join
from pathlib import Path

# %%
DATADIR = Path(_dh[0]).parent / "data"

# %% [markdown]
# ## Collect fragment info from Mpro data

# %%
def generate_3D(mol):
    """
    helper function to generate 3D conformations
    """
    m2 = Chem.AddHs(mol)
    AllChem.EmbedMolecule(m2)
    AllChem.UFFOptimizeMolecule(m2)
    return m2

# %% [markdown]
# ### non covalent

# %%
# collect file names
# mypath = DATADIR + '/fragments/non-covalent/'
# files_noncov = [f for f in listdir(mypath) if isfile(join(mypath, f))]
files_noncov = [
    "Mpro-x0072.pdb",
    "Mpro-x0104.pdb",
    "Mpro-x0107.pdb",
    "Mpro-x0161.pdb",
    "Mpro-x0195.pdb",
    "Mpro-x0305.pdb",
    "Mpro-x0354.pdb",
    "Mpro-x0387.pdb",
    "Mpro-x0395.pdb",
    "Mpro-x0397.pdb",
    "Mpro-x0426.pdb",
    "Mpro-x0434.pdb",
    "Mpro-x0540.pdb",
    "Mpro-x0678.pdb",
    "Mpro-x0874.pdb",
    "Mpro-x0946.pdb",
    "Mpro-x0967.pdb",
    "Mpro-x0991.pdb",
    "Mpro-x0995.pdb",
    "Mpro-x1077.pdb",
    "Mpro-x1093.pdb",
    "Mpro-x1249.pdb",
]
print(len(files_noncov))
# Out:
# 22

# %% [markdown]
# ### covalent

# %%
# collect file names
# mypath =DATADIR + '/fragments/covalent/'
# files_cov = [f for f in listdir(mypath) if isfile(join(mypath, f))]
files_cov = [
    "Mpro-x0689.pdb",
    "Mpro-x0691.pdb",
    "Mpro-x0692.pdb",
    "Mpro-x0705.pdb",
    "Mpro-x0708.pdb",
    "Mpro-x0731.pdb",
    "Mpro-x0734.pdb",
    "Mpro-x0736.pdb",
    "Mpro-x0749.pdb",
    "Mpro-x0752.pdb",
    "Mpro-x0755.pdb",
    "Mpro-x0759.pdb",
    "Mpro-x0769.pdb",
    "Mpro-x0770.pdb",
    "Mpro-x0771.pdb",
    "Mpro-x0774.pdb",
    "Mpro-x0786.pdb",
    "Mpro-x0820.pdb",
    "Mpro-x0830.pdb",
    "Mpro-x0831.pdb",
    "Mpro-x0978.pdb",
    "Mpro-x0981.pdb",
    "Mpro-x1308.pdb",
    "Mpro-x1311.pdb",
    "Mpro-x1334.pdb",
    "Mpro-x1336.pdb",
    "Mpro-x1348.pdb",
    "Mpro-x1351.pdb",
    "Mpro-x1358.pdb",
    "Mpro-x1374.pdb",
    "Mpro-x1375.pdb",
    "Mpro-x1380.pdb",
    "Mpro-x1382.pdb",
    "Mpro-x1384.pdb",
    "Mpro-x1385.pdb",
    "Mpro-x1386.pdb",
    "Mpro-x1392.pdb",
    "Mpro-x1402.pdb",
    "Mpro-x1412.pdb",
    "Mpro-x1418.pdb",
    "Mpro-x1425.pdb",
    "Mpro-x1458.pdb",
    "Mpro-x1478.pdb",
    "Mpro-x1493.pdb",
]
print(len(files_cov))
# Out:
# 44

# %%
# read full frgament csv file
df = pd.read_csv(
    DATADIR
    / "Mpro full XChem screen - experiment summary - ver-2020-03-25-annotated.csv",
    sep=";",
    index_col=0,
)
df
# Out:
#             CompoundCode                    CompoundSMILES  \
# CrystalName
# Mpro-x0001          DMSO                               NaN
# Mpro-x0002          DMSO                               NaN
# Mpro-x0003          DMSO                               NaN
# Mpro-x0004          DMSO                               NaN
# Mpro-x0005          DMSO                               NaN
# ...                  ...                               ...
# NaN          PCM-0102974  CC(C)N(C)C(=O)C1CCN(CC1)C(=O)CCl
# NaN          PCM-0102275       CC(NC(=O)CCl)c1cccc2ccccc12
# NaN          PCM-0102879      CC(NC(=O)CCl)c1cc(C)c(C)cc1C
# NaN          PCM-0102190         CC(NC(=O)CCl)c1cccc(Cl)c1
# NaN          PCM-0102425   ClCC(=O)N1CCCC(C1)c2nc3ccccc3s2
#
#                           MountingResult    DataCollectionOutcome  \
# CrystalName
# Mpro-x0001     OK: No comment:No comment  Failed - low resolution
# Mpro-x0002     OK: No comment:No comment  Failed - low resolution
# Mpro-x0003     OK: No comment:No comment  Failed - low resolution
# Mpro-x0004     OK: No comment:No comment                  success
# Mpro-x0005     OK: No comment:No comment                  success
# ...                                  ...                      ...
# NaN          FAIL: No comment:No comment                      NaN
# NaN          FAIL: No comment:No comment                      NaN
# NaN          FAIL: No comment:No comment                      NaN
# NaN          FAIL: No comment:No comment                      NaN
# NaN          FAIL: No comment:No comment                      NaN
#
#             DataProcessingResolutionHigh        RefinementOutcome  \
# CrystalName
# Mpro-x0001                          7,11                      NaN
# Mpro-x0002                          5,21                      NaN
# Mpro-x0003                          4,14                      NaN
# Mpro-x0004                          2,71  7 - Analysed & Rejected
# Mpro-x0005                           1,8  7 - Analysed & Rejected
# ...                                  ...                      ...
# NaN                                  NaN                      NaN
# NaN                                  NaN                      NaN
# NaN                                  NaN                      NaN
# NaN                                  NaN                      NaN
# NaN                                  NaN                      NaN
#
#             Deposition_PDB_ID
# CrystalName
# Mpro-x0001                NaN
# Mpro-x0002                NaN
# Mpro-x0003                NaN
# Mpro-x0004                NaN
# Mpro-x0005                NaN
# ...                       ...
# NaN                       NaN
# NaN                       NaN
# NaN                       NaN
# NaN                       NaN
# NaN                       NaN
#
# [1923 rows x 7 columns]

# %% [markdown]
# ### Extract info for non-covalent fragments

# %%
df_frag = pd.DataFrame(columns=["name", "smiles", "mol"])
idx = 0
for f in files_noncov:
    frag_name = Path(f).stem
    if frag_name in df.index:
        smiles = df.loc[frag_name]["CompoundSMILES"]
        mol = AllChem.MolFromSmiles(smiles)
        mol.SetProp("_Name", frag_name)
        df_frag.loc[idx] = [frag_name, smiles, mol]
        idx += 1

# %%
df_frag["mol3D"] = df_frag["mol"].apply(generate_3D)
df_frag.head()
# Out:
#          name                          smiles  \
# 0  Mpro-x0072        CS(=O)(=O)NCCC=1C=CC=CC1
# 1  Mpro-x0104   CC(=O)NCCC1=CNC=2C=CC(F)=CC12
# 2  Mpro-x0107             CC(=O)NC=1C=NC=CC1C
# 3  Mpro-x0161  COC(=O)C=1C=CC(=CC1)S(=O)(=O)N
# 4  Mpro-x0195  CN1CCCC=2C=CC(=CC12)S(=O)(=O)N
#
#                                                 mol  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7fb3da093f30>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7fb3da14d800>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7fb3da1b1760>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7fb3da1b1440>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7fb3da136d00>
#
#                                               mol3D
# 0  <rdkit.Chem.rdchem.Mol object at 0x7fb3da093c60>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7fb3da0da030>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7fb3da0da9e0>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7fb3da05aa30>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7fb3da05aad0>

# %%
Draw.MolsToGridImage(df_frag.mol, molsPerRow=5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x1000 at 0x7FB3DA063EB8>

# %%
# save molecules to sdf
fname = "non_covalent_fragments"
w = Chem.SDWriter(str(DATADIR / "fragments" / f"{fname}_2D.sdf"))
for m in df_frag.mol:
    w.write(m)
w.close()

# %%
# generate 3D if needed
# w = Chem.SDWriter(str(DATADIR / "fragments" / f"{fname}_3D.sdf"))
# for m in df_frag.mol3D: w.write(m)
# w.close()

# %% [markdown]
# ### Extract info for covalent fragments

# %%
df_frag = pd.DataFrame(columns=["name", "smiles", "mol"])
idx = 0
for f in files_cov:
    frag_name = Path(f).stem
    if frag_name in df.index:
        smiles = df.loc[frag_name]["CompoundSMILES"]
        mol = AllChem.MolFromSmiles(smiles)
        mol.SetProp("_Name", frag_name)
        df_frag.loc[idx] = [frag_name, smiles, mol]
        idx += 1

# %%
df_frag["mol3D"] = df_frag["mol"].apply(generate_3D)
df_frag.head()
# Out:
#          name                                  smiles  \
# 0  Mpro-x0689      ClCC(=O)N1CCN(CC1)S(=O)(=O)c2cccs2
# 1  Mpro-x0691  Fc1cccc(c1)S(=O)(=O)N2CCN(CC2)C(=O)CCl
# 2  Mpro-x0692          Cc1cccc(CN2CCN(CC2)C(=O)CCl)c1
# 3  Mpro-x0705      Cc1ccc(cc1)C(=O)N2CCN(CC2)C(=O)CCl
# 4  Mpro-x0708            ClCC(=O)NNC(=O)c1cc2CCCCc2s1
#
#                                                 mol  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7fb3da123e40>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7fb3da136a80>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7fb3da136b70>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7fb3da1b16c0>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07fc60>
#
#                                               mol3D
# 0  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07fda0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07fb70>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07f800>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07f7b0>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7fb3da07f760>

# %%
Draw.MolsToGridImage(df_frag.mol, molsPerRow=5)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x1800 at 0x7FB3DA05C630>

# %%
# save molecules to sdf
fname = "covalent_fragments"
w = Chem.SDWriter(str(DATADIR / "fragments" / f"{fname}_2D.sdf"))
for m in df_frag.mol:
    w.write(m)
w.close()

# %%
# generate 3D if needed
# w = Chem.SDWriter(str(DATADIR / "fragments" / f"{fname}_3D.sdf"))
# for m in df_frag.mol3D: w.write(m)
# w.close()
